# %% [markdown]
# # Nikkei 225 Time Series Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
# %run -i 'data/nikkei_data.py'

# %%
# get data
nikkei.head()
# Out:
#                 Points
# Date
# 2000-01-31  18905.6333
# 2000-02-29  19686.6990
# 2000-03-31  19823.0500
# 2000-04-30  19517.6720
# 2000-05-31  17222.5004

# %%
# create train data and validation data
train_length = int(len(nikkei)*0.9)
nikkei_train = nikkei[:train_length]
nikkei_valid = nikkei[train_length:]

# %%
plt.figure(figsize=(18, 8))
plt.plot(nikkei_train.index, nikkei_train['Points'])
plt.xlabel('Date')
plt.ylabel('Points')
plt.title("Training Data")
plt.show()
