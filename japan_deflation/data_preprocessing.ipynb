# %%
import pandas as pd

# %%
all_data = pd.read_csv('data/data.csv')
all_data.head()
# Out:
#              Series Name        Series Code   Country Name Country Code  \
# 0  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG  United States          USA
# 1  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG          China          CHN
# 2  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG          Japan          JPN
# 3  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG        Germany          DEU
# 4  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG          India          IND
#
#       2000 [YR2000]      2001 [YR2001]       2002 [YR2002]  \
# 0  4.12748401355853    0.9983407946565     1.7416952497298
# 1  8.49150849150864   8.33991054985535    9.13064594463313
# 2  2.77963282527575  0.406335903186886   0.117992776763344
# 3  2.89518694712132   1.69773236086638  -0.198459062728844
# 4  3.84099115681285   4.82396626390644    3.80397532137577
#
#         2003 [YR2003]     2004 [YR2004]      2005 [YR2005]  ...  \
# 0    2.86121076741024  3.79889112662393   3.51321379665302  ...
# 1    10.0356030262573  10.1112234580385   11.3957759412304  ...
# 2    1.52822014815892  2.20468788231713     1.662670405184  ...
# 3  -0.713533477235572  1.18991490034335  0.721853764966724  ...
# 4    7.86038147553259  7.92293661286503   7.92343062149763  ...
#
#       2010 [YR2010]       2011 [YR2011]     2012 [YR2012]      2013 [YR2013]  \
# 0  2.56376655876581    1.55083550568156  2.24954585236992   1.84208107101102
# 1  10.6361404632299    9.55091409001014   7.8596274932851   7.76861528412806
# 2  4.19173925858955  -0.115421339717841  1.49508958594926    2.0002678411015
# 3   4.1789690378929    3.92413341771297  0.41955108005358  0.428243261672193
# 4  8.49758470158106     5.2413447428854  5.45635895072287   6.38610640094825
#
#        2014 [YR2014]     2015 [YR2015]      2016 [YR2016]     2017 [YR2017]  \
# 0   2.45197303536034  2.88091046605219   1.56721516997864  2.21701033031884
# 1   7.29951892117124  6.90531667019702   6.73667525262536  6.75700761091511
# 2  0.374719476331322  1.22292104108077  0.609093181244134  1.92875725125687
# 3   2.22568874914928  1.73974982269824   2.22999996699747  2.46503002917808
# 4   7.41022760508852  7.99625378571471   8.16952650547138  7.16788886086535
#
#        2018 [YR2018] 2019 [YR2019]
# 0   2.92732272821085            ..
# 1   6.56697385961871            ..
# 2  0.788455875670337            ..
# 3   1.52744629830981            ..
# 4   6.81136932613997            ..
#
# [5 rows x 24 columns]

# %% [markdown]
# Drop last five columns as they are not relevant.

# %%
all_data = all_data.iloc[:-5, :]

# %% [markdown]
# Get all the name of the dataset imported.

# %%
data_name = all_data['Series Name'].unique()
data_dict = dict(zip(list(range(len(data_name))), data_name))
data_dict
# Out:
# {0: 'GDP growth (annual %)',
#  1: 'GDP per capita (constant 2010 US$)',
#  2: 'Imports of goods and services (% of GDP)',
#  3: 'Exports of goods and services (% of GDP)',
#  4: 'Government expenditure on education, total (% of GDP)',
#  5: 'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#  6: 'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#  7: 'Broad money (% of GDP)',
#  8: 'Binding coverage, all products (%)',
#  9: 'Labor tax and contributions (% of commercial profits)',
#  10: 'Other taxes (% of revenue)',
#  11: 'Profit tax (% of commercial profits)',
#  12: 'Tariff rate, applied, simple mean, all products (%)',
#  13: 'Tax payments (number)',
#  14: 'Tax revenue (% of GDP)',
#  15: 'Taxes on goods and services (% of revenue)',
#  16: 'Total reserves (includes gold, current US$)',
#  17: 'Central government debt, total (current LCU)',
#  18: 'Consumer price index (2010 = 100)',
#  19: 'Export value index (2000 = 100)',
#  20: 'External balance on goods and services (current US$)',
#  21: 'Final consumption expenditure (current US$)',
#  22: 'Food production index (2004-2006 = 100)',
#  23: 'Foreign direct investment, net (BoP, current US$)',
#  24: 'Fuel exports (% of merchandise exports)',
#  25: 'Fuel imports (% of merchandise imports)',
#  26: 'GDP (current US$)',
#  27: 'GDP deflator (base year varies by country)',
#  28: 'GDP per capita (current US$)',
#  29: 'GDP per capita growth (annual %)',
#  30: 'General government final consumption expenditure (current US$)',
#  31: 'GNI (current US$)',
#  32: 'GNI per capita, PPP (current international $)',
#  33: 'Gross capital formation (current US$)',
#  34: 'Gross domestic income (constant LCU)',
#  35: 'Gross domestic savings (current US$)',
#  36: 'Gross national expenditure (current US$)',
#  37: 'Gross savings (current US$)',
#  38: 'Human capital index (HCI) (scale 0-1)',
#  39: 'ICT goods exports (% of total goods exports)',
#  40: 'ICT goods imports (% total goods imports)',
#  41: 'ICT service exports (BoP, current US$)',
#  42: 'Import value index (2000 = 100)',
#  43: 'Imports of goods and services (current US$)',
#  44: 'Individuals using the Internet (% of population)',
#  45: 'Inflation, consumer prices (annual %)',
#  46: 'Interest payments (% of expense)',
#  47: 'Interest payments (% of revenue)',
#  48: 'International tourism, expenditures (current US$)',
#  49: 'International tourism, receipts (current US$)',
#  50: 'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#  51: 'Livestock production index (2004-2006 = 100)',
#  52: 'Logistics performance index: Overall (1=low to 5=high)',
#  53: 'Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)',
#  54: 'Manufactures exports (% of merchandise exports)',
#  55: 'Manufactures imports (% of merchandise imports)',
#  56: 'Manufacturing, value added (current US$)',
#  57: 'Market capitalization of listed domestic companies (current US$)',
#  58: 'Merchandise exports (current US$)',
#  59: 'Merchandise imports (current US$)',
#  60: 'Military expenditure (current USD)',
#  61: 'Net capital account (BoP, current US$)',
#  62: 'Net domestic credit (current LCU)',
#  63: 'Net errors and omissions (BoP, current US$)',
#  64: 'Net financial account (BoP, current US$)',
#  65: 'Net foreign assets (current LCU)',
#  66: 'Net investment in nonfinancial assets (current LCU)',
#  67: 'Net primary income (Net income from abroad) (current US$)',
#  68: 'Net trade in goods (BoP, current US$)',
#  69: 'Net trade in goods and services (BoP, current US$)',
#  70: 'Patent applications, residents',
#  71: 'Patent applications, nonresidents',
#  72: 'Population ages 65 and above, total',
#  73: 'Population ages 65 and above (% of total population)',
#  74: 'Population growth (annual %)',
#  75: 'Portfolio equity, net inflows (BoP, current US$)',
#  76: 'Portfolio investment, net (BoP, current US$)',
#  77: 'PPP conversion factor, GDP (LCU per international $)',
#  78: 'Real effective exchange rate index (2010 = 100)',
#  79: 'Real interest rate (%)',
#  80: 'Research and development expenditure (% of GDP)',
#  81: 'Reserves and related items (BoP, current US$)',
#  82: 'Revenue, excluding grants (% of GDP)',
#  83: 'Rural population (% of total population)',
#  84: 'S&P Global Equity Indices (annual % change)',
#  85: 'Stocks traded, total value (% of GDP)',
#  86: 'Total tax and contribution rate (% of profit)',
#  87: 'Trade (% of GDP)',
#  88: 'Wholesale price index (2010 = 100)',
#  89: 'Net investment in nonfinancial assets (% of GDP)'}

# %%
all_data.loc[all_data['Series Name'] == data_dict[0]].iloc[0]
# Out:
# Series Name      GDP growth (annual %)
# Series Code          NY.GDP.MKTP.KD.ZG
# Country Name             United States
# Country Code                       USA
# 2000 [YR2000]         4.12748401355853
# 2001 [YR2001]          0.9983407946565
# 2002 [YR2002]          1.7416952497298
# 2003 [YR2003]         2.86121076741024
# 2004 [YR2004]         3.79889112662393
# 2005 [YR2005]         3.51321379665302
# 2006 [YR2006]         2.85497229170015
# 2007 [YR2007]         1.87617145846693
# 2008 [YR2008]       -0.136579805460741
# 2009 [YR2009]        -2.53675706585665
# 2010 [YR2010]         2.56376655876581
# 2011 [YR2011]         1.55083550568156
# 2012 [YR2012]         2.24954585236992
# 2013 [YR2013]         1.84208107101102
# 2014 [YR2014]         2.45197303536034
# 2015 [YR2015]         2.88091046605219
# 2016 [YR2016]         1.56721516997864
# 2017 [YR2017]         2.21701033031884
# 2018 [YR2018]         2.92732272821085
# 2019 [YR2019]                       ..
# Name: 0, dtype: object
